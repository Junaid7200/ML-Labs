# %% [markdown]
# # start flask app and connect sqlalchemy
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# # Creating tables using sqlalchemy
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# # Template Inheritence using Jinja
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# # Using sqlalchemy to make POST requests
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# # Using sqlalchemy to make GET requests
#
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# # Parameterized routes in Flask
#
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# # App context to create db
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# # Connecting and using tailwindcss with flask and jinja
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - `npx @tailwindcss/cli -i ./static/src/input.css -o ./static/dist/output.css --watch`
# - `npm install -D tailwindcss`
# - `npm install -D @tailwindcss/cli`

# %% [markdown]
# ---

# %% [markdown]
# # Editting a record in flask and sqlalchemy
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - use route params to get id and fetch the record using id.
# - if posting (user is entering data into form), update the record (post part of the update)
# - if not posting, show the form to the user so he can post (get part of the update basically)

# %% [markdown]
# ---
