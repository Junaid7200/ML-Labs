# %% [markdown]
# # **Tasks**
#
# - **Text Classification**
# - **summarization**
# - **language translation (at least 5 languages)**
# - **Image to text**
# - **Text to image**

# %% [markdown]
# ## Sentiment Analysis / Text classification

# %%
import numpy
import transformers

print("numpy __version__:", numpy.__version__)
print("transformers __version__:", transformers.__version__)
# Out:
# numpy __version__: 1.26.4
# transformers __version__: 4.46.3

# %%
from transformers import pipeline

classifier = pipeline(
    "text-classification", model="j-hartmann/emotion-english-distilroberta-base", return_all_scores=True
)
classifier("Yo HT! hope you're doing well mate.")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/294 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# w:\7_Semester\Machine Learning\labs\.venv\Lib\site-packages\transformers\pipelines\text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# [[{'label': 'anger', 'score': 0.012347746640443802},
#   {'label': 'disgust', 'score': 0.0034388036001473665},
#   {'label': 'fear', 'score': 0.0016802317695692182},
#   {'label': 'joy', 'score': 0.5841454863548279},
#   {'label': 'neutral', 'score': 0.28166690468788147},
#   {'label': 'sadness', 'score': 0.0183815136551857},
#   {'label': 'surprise', 'score': 0.09833937883377075}]]
# model.safetensors:   0%|          | 0.00/329M [00:00<?, ?B/s]

# %% [markdown]
# ---

# %% [markdown]
# # Summarization

# %%
summarizer = pipeline("summarization", model="t5-small")
ARTICLE = """
As companies increasingly adopt biometric time clock systems, you may wonder about the implications of using your fingerprint to clock in and out of work. While these systems promise enhanced security and efficiency, they raise important concerns regarding privacy and health.

Many employers view fingerprint scanners as a modern solution for tracking attendance, reducing instances of "time theft" where employees might punch in for one another. However, these machines rely on your unique biometric data, which brings risks associated with personal privacy and security.

With the recent COVID-19 pandemic, health concerns have also come to the forefront. Shared screens and fingerprint scanners can harbor viruses, emphasizing the need for regular cleaning and proper hygiene practices, such as handwashing or using sanitizer after use.

Critics highlight significant risks tied to biometric data, including potential identity theft and unauthorized surveillance. As privacy advocates like the ACLU point out, biometric information is permanent and cannot be changed like a password or credit card number. This immutability puts individuals at risk for long-term consequences if their data is compromised.

Various companies, from fast-food chains to airlines, have faced legal challenges regarding their use of biometric systems. Some argue that collective bargaining agreements with employee unions permit their use, while others have remained silent amid ongoing litigation.

As laws surrounding privacy and biometrics evolve, some states have enacted regulations to protect employees. In certain jurisdictions, you may have the right to refuse the use of biometric time clocks and even take legal action if necessary.
"""

# %%
summarizer(ARTICLE, max_length=130, min_length=30)
# Out:
# [{'summary_text': 'biometric time clock systems rely on your unique biometric data . biometric information is permanent and cannot be changed like a password or credit card number . some states have enacted regulations to protect employees .'}]

# %% [markdown]
# ---

# %% [markdown]
# ## Language Translator

# %% [markdown]
# ### English to Urdu

# %%
translator_eng_to_urdu = pipeline("translation", model="Helsinki-NLP/opus-mt-en-ur")
ARTICLE = """
Reading books expands your knowledge.
"""

translator_eng_to_urdu(ARTICLE)
# Out:
# [{'translation_text': 'کتابیں پڑھنے سے آپ کے علم میں اضافہ ہوتا ہے ۔'}]

# %% [markdown]
# ### Urdu to English

# %%
translator_urdu_to_eng = pipeline("translation", model="Helsinki-NLP/opus-mt-ur-en")
ARTICLE = """
کتابیں پڑھنے سے آپ کے علم میں اضافہ ہوتا ہے 
"""
translator_urdu_to_eng(ARTICLE)
# Out:
# [{'translation_text': 'Reading Your Book will increase your knowledge of you'}]

# %% [markdown]
# ### Arabic to English

# %%
translator_ar_to_en = pipeline("translation", model="Helsinki-NLP/opus-mt-ar-en")
ARTICLE = """"
قراءة الكتب توسع معرفتك.
"""
translator_ar_to_en(ARTICLE)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/917k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# [{'translation_text': '"Reading books expands your knowledge.'}]

# %% [markdown]
# ### English to Arabic

# %%
translator_en_to_ar = pipeline("translation", model="Helsinki-NLP/opus-mt-en-ar")
ARTICLE = """
Reading books expands your knowledge.
"""
translator_en_to_ar(ARTICLE)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/801k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/917k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# [{'translation_text': 'الكتب المقروءة توسع معرفتك'}]

# %% [markdown]
# ### Arabic to french

# %%
translator_ar_to_fr = pipeline("translation", model="Helsinki-NLP/opus-mt-ar-fr")
ARTICLE = """
قراءة الكتب توسع معرفتك."""
translator_ar_to_fr(ARTICLE)

# %% [markdown]
# # Image to text

# %%
img_to_text = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
img_to_text("https://images.mubicdn.net/images/film/253853/cache-502580-1745496686/image-w1280.jpg?size=800x")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# w:\7_Semester\Machine Learning\labs\.venv\Lib\site-packages\transformers\generation\utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': 'the legend of heroes episode 2'}]

# %% [markdown]
# ### Text to Image

# %%
from huggingface_hub import InferenceClient
from PIL import Image
from io import BytesIO

# %%
import os
from dotenv import load_dotenv

load_dotenv()
token = os.environ["HF_FINEGRAINED_APIKEY"]

model_id = "stabilityai/stable-diffusion-3-medium-diffusers"
# Or try: "black-forest-labs/FLUX.1-schnell"
# Or try: "black-forest-labs/FLUX.1-dev"

client = InferenceClient(model=model_id, token=token)
prompt = "A guy standing in front of a mosque during sunset, digital art"

img_bytes = client.text_to_image(prompt)
img = client.text_to_image(prompt)
img.save("mosque_image.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
