# %% [markdown]
# # 1. RAG Structure
#
# - Find the data  you need to give to your LLM
# - embed the data and store in a vector database for cosine similarity lookup
# - during embedding, you will need to learn chunking
# - when a query comes, embed the query and perform similarity
